# %%
import pandas as pd

# Cargar archivo CSV
df = pd.read_csv(
    "C:/Users/Administrator/Desktop/Proyecto Personal_Estudio de la Procesionaria/dataset/clima_combinado.csv",
    on_bad_lines='skip',delimiter=';')

# Vista previa de los datos
print(df.head())
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_1464\2765120215.py:4: DtypeWarning: Columns (18,33,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
#   Diario.COD_EST         Diario.FECHA  Diario.T_MAX  Diario.T_MED  \
# 0          AL001  2002-01-01T00:00:00         14.93      13.36750
# 1          AL001  2002-01-02T00:00:00         16.63      13.17250
# 2          AL001  2002-01-03T00:00:00         14.55      11.00208
# 3          AL001  2002-01-04T00:00:00         17.95      11.31500
# 4          AL001  2002-01-05T00:00:00         13.67      12.39000
#
#    Diario.T_MIN  Diario.H_R_MAX  Diario.H_R_MED  Diario.H_R_MIN  \
# 0         12.09            90.2        80.53333            74.8
# 1         10.65            86.6        74.93333            62.5
# 2          7.09            93.3        88.42081            77.7
# 3          4.55            95.0        76.27915            47.2
# 4         11.07            88.1        74.89584            60.8
#
#    Diario.RADIACION  Diario.LLUVIA  ...  \
# 0          2.385900            0.0  ...
# 1          7.791800            0.0  ...
# 2          2.841113            0.0  ...
# 3          9.970669            0.1  ...
# 4          3.165156            1.8  ...
#
#    Cns_OpenData_ActualizarFcha.Lluvia_acum  Cns_OpenData_ActualizarFcha.V_Max  \
# 0                                      NaN                                NaN
# 1                                      NaN                                NaN
# 2                                      NaN                                NaN
# 3                                      NaN                                NaN
# 4                                      NaN                                NaN
#
#    Cns_OpenData_ActualizarFcha.V_Med  Cns_OpenData_ActualizarFcha.V_Min  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2                                NaN                                NaN
# 3                                NaN                                NaN
# 4                                NaN                                NaN
#
#    Cns_OpenData_ActualizarFcha.CV1  Cns_OpenData_ActualizarFcha.CV2  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    Cns_OpenData_ActualizarFcha.CV3  Cns_OpenData_ActualizarFcha.CV4  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#   Cns_OpenData_ActualizarFcha.Direccion  Attribute:generated
# 0                                   NaN                  NaN
# 1                                   NaN                  NaN
# 2                                   NaN                  NaN
# 3                                   NaN                  NaN
# 4                                   NaN                  NaN
#
# [5 rows x 211 columns]

# %%
# Información general sobre el DataFrame
print(df.info())

# Estadísticas descriptivas para datos numéricos
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610397 entries, 0 to 610396
# Columns: 211 entries, Diario.COD_EST to Attribute:generated
# dtypes: float64(206), object(5)
# memory usage: 982.6+ MB
# None
#         Diario.T_MAX   Diario.T_MED   Diario.T_MIN  Diario.H_R_MAX  \
# count  608763.000000  608839.000000  608786.000000   608556.000000
# mean       23.374034      16.738611      10.666726       81.684710
# std        24.448347      11.356531       6.316024       36.349182
# min        -9.440000      -9.580000     -65.580000       -0.053000
# 25%        16.690000      10.957835       6.010000       72.500000
# 50%        22.710000      16.263750      10.710000       86.300000
# 75%        30.000000      22.599170      15.610000       94.300000
# max      7991.000000    3440.875000     142.000000     7964.000000
#
#        Diario.H_R_MED  Diario.H_R_MIN  Diario.RADIACION  Diario.LLUVIA  \
# count   608927.000000   608556.000000     609642.000000  608659.000000
# mean        61.333479       39.183164         10.971732       1.272610
# std         24.671090       29.940174         10.555390       6.674318
# min      -3970.175833    -7999.000000        -28.796400       0.000000
# 25%         47.035833       23.640000          0.929444       0.000000
# 50%         62.947910       36.500000          8.847296       0.000000
# 75%         76.186075       52.800000         20.107335       0.100000
# max       5166.875000      774.000000        143.294400    3144.000000
#
#        Diario.LLUVIA_MIN  Diario.T_S_MAX  ...  \
# count      598408.000000   492288.000000  ...
# mean           41.079963       11.332047  ...
# std           129.650023       11.198499  ...
# min             0.000000       -3.559000  ...
# 25%             0.000000        3.194583  ...
# 50%             0.000000        8.874542  ...
# 75%            19.800000       17.504687  ...
# max          1440.000000     2025.000000  ...
#
#        Cns_OpenData_ActualizarFcha.Lluvia_acum  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        Cns_OpenData_ActualizarFcha.V_Max  Cns_OpenData_ActualizarFcha.V_Med  \
# count                                0.0                                0.0
# mean                                 NaN                                NaN
# std                                  NaN                                NaN
# min                                  NaN                                NaN
# 25%                                  NaN                                NaN
# 50%                                  NaN                                NaN
# 75%                                  NaN                                NaN
# max                                  NaN                                NaN
#
#        Cns_OpenData_ActualizarFcha.V_Min  Cns_OpenData_ActualizarFcha.CV1  \
# count                                0.0                              0.0
# mean                                 NaN                              NaN
# std                                  NaN                              NaN
# min                                  NaN                              NaN
# 25%                                  NaN                              NaN
# 50%                                  NaN                              NaN
# 75%                                  NaN                              NaN
# max                                  NaN                              NaN
#
#        Cns_OpenData_ActualizarFcha.CV2  Cns_OpenData_ActualizarFcha.CV3  \
# count                              0.0                              0.0
# mean                               NaN                              NaN
# std                                NaN                              NaN
# min                                NaN                              NaN
# 25%                                NaN                              NaN
# 50%                                NaN                              NaN
# 75%                                NaN                              NaN
# max                                NaN                              NaN
#
#        Cns_OpenData_ActualizarFcha.CV4  Cns_OpenData_ActualizarFcha.Direccion  \
# count                              0.0                                    0.0
# mean                               NaN                                    NaN
# std                                NaN                                    NaN
# min                                NaN                                    NaN
# 25%                                NaN                                    NaN
# 50%                                NaN                                    NaN
# 75%                                NaN                                    NaN
# max                                NaN                                    NaN
#
#        Attribute:generated
# count                  0.0
# mean                   NaN
# std                    NaN
# min                    NaN
# 25%                    NaN
# 50%                    NaN
# 75%                    NaN
# max                    NaN
#
# [8 rows x 206 columns]

# %%
#Información del nombre de las columnas
print(df.columns)
# Out:
# Index(['Diario.COD_EST', 'Diario.FECHA', 'Diario.T_MAX', 'Diario.T_MED',
#        'Diario.T_MIN', 'Diario.H_R_MAX', 'Diario.H_R_MED', 'Diario.H_R_MIN',
#        'Diario.RADIACION', 'Diario.LLUVIA',
#        ...
#        'Cns_OpenData_ActualizarFcha.Lluvia_acum',
#        'Cns_OpenData_ActualizarFcha.V_Max',
#        'Cns_OpenData_ActualizarFcha.V_Med',
#        'Cns_OpenData_ActualizarFcha.V_Min', 'Cns_OpenData_ActualizarFcha.CV1',
#        'Cns_OpenData_ActualizarFcha.CV2', 'Cns_OpenData_ActualizarFcha.CV3',
#        'Cns_OpenData_ActualizarFcha.CV4',
#        'Cns_OpenData_ActualizarFcha.Direccion', 'Attribute:generated'],
#       dtype='object', length=211)

# %%
# Contar valores nulos por columna
print(df.isnull().sum())

# Porcentaje de valores nulos por columna
missing_percentage = df.isnull().sum() / len(df) * 100
print(missing_percentage)
# Out:
# Diario.COD_EST                                0
# Diario.FECHA                                  0
# Diario.T_MAX                               1634
# Diario.T_MED                               1558
# Diario.T_MIN                               1611
#                                           ...
# Cns_OpenData_ActualizarFcha.CV2          610397
# Cns_OpenData_ActualizarFcha.CV3          610397
# Cns_OpenData_ActualizarFcha.CV4          610397
# Cns_OpenData_ActualizarFcha.Direccion    610397
# Attribute:generated                      610397
# Length: 211, dtype: int64
# Diario.COD_EST                             0.000000
# Diario.FECHA                               0.000000
# Diario.T_MAX                               0.267695
# Diario.T_MED                               0.255244
# Diario.T_MIN                               0.263927
#                                             ...
# Cns_OpenData_ActualizarFcha.CV2          100.000000
# Cns_OpenData_ActualizarFcha.CV3          100.000000
# Cns_OpenData_ActualizarFcha.CV4          100.000000
# Cns_OpenData_ActualizarFcha.Direccion    100.000000
# Attribute:generated                      100.000000
# Length: 211, dtype: float64

# %%
# Eliminar columnas con más del 30% de valores nulos
threshold = 30
columns_to_drop = missing_percentage[missing_percentage > threshold].index
df = df.drop(columns=columns_to_drop)

# Eliminar filas con valores nulos
#df = df.dropna()

# Imputar valores nulos (ejemplo: usar la media)
#df.fillna(df.mean(), inplace=True)

# %%
df
