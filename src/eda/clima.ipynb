# %%
import pandas as pd

# Cargar archivo CSV
df = pd.read_csv("C:/Users/Administrator/Desktop/Proyecto Personal_Estudio de la Procesionaria/dataset/clima_combinado.csv")

# Vista previa de los datos
print(df.head())
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_11948\3750242640.py:4: DtypeWarning: Columns (0,1,2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:/Users/Administrator/Desktop/Proyecto Personal_Estudio de la Procesionaria/dataset/clima_combinado.csv")
#   Diario.COD_EST;Diario.FECHA;Diario.T_MAX;Diario.T_MED;Diario.T_MIN;Diario.H_R_MAX;Diario.H_R_MED;Diario.H_R_MIN;Diario.RADIACION;Diario.LLUVIA;Diario.LLUVIA_MIN;Diario.T_S_MAX;Diario.T_S_MED;Diario.T_S_MIN;Diario.V_MAX;Diario.V_MED;Diario.V_MIN;Diario.CV1;Diario.CV2;Diario.CV3;Diario.CV4;Diario.DIRECCION;Diario.HORAS;Diario.H_T;Diario.H_HR;Diario.H_R;Diario.H_LL;Diario.H_TS;Diario.H_V;Diario.H_D;Diario.CALCULOS;Diario.MTMEN0;Diario.MTMEN7;Diario.MTMA30;Diario.MVMA50;Attribute:generated  \
# 0  AL001;2002-01-01T00:00:00;14.93;13.3675;12.09;...
# 1  AL001;2002-01-02T00:00:00;16.63;13.1725;10.65;...
# 2  AL001;2002-01-03T00:00:00;14.55;11.00208;7.09;...
# ...
